# %% [markdown]
# <a href="https://colab.research.google.com/github/nol-smith/BTE320/blob/In-Class-Assignments/InClass_ClassMethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Greeting:
  def __init__(self, first, last):
    self.first = first
    self.last = last


  def display(self, formal=False):
    if formal:
      print(f'Hello {self.first} {self.last}')
    else:
      print(f'Hi {self.first}')

  def __str__(self):
    return f'{self.first},{self.last}'

  def __repr__(self):
    return f'{self.first},{self.last}'

greeting = Greeting('Donald','Becker')
greeting2 = Greeting('Bob','Dylan')
greeting.display(formal=True)
greeting2.display(formal=False)
print(greeting)
print(greeting2)
# Out:
# Hello Donald Becker
# Hi Bob
# Donald,Becker
# Bob,Dylan

# %% [markdown]
# # Add a named parameter to the display method, with signature: def display(self, formal=False)
# # Enhance the display method:
# if formal is true, display hello <first><last>
# if formal is false, display Hi <first>
#
# #Test your enhanced class:
# greeting = Greeting('Donald, 'Becker')
# greeting.display(formal=true)
