# %% [markdown]
# <a href="https://colab.research.google.com/github/nol-smith/BTE320/blob/In-Class-Assignments/InClass5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = []

while True:
    user_input = int(input("Enter a number (0 to exit): "))

    if user_input == 0:
        break

    numbers.append(user_input)

numbers.sort(reverse=True)
print(numbers)
# Out:
# Enter a number (0 to exit): 1
# Enter a number (0 to exit): 2
# Enter a number (0 to exit): 4
# Enter a number (0 to exit): 7
# Enter a number (0 to exit): 0
# [7, 4, 2, 1]
